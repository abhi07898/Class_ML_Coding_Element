# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.utils import np_utils

# %%
from keras.datasets import boston_housing
(X_train, y_train,),(X_test , y_test) = boston_housing.load_data()

# %%
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (404, 13) (404,)
# (102, 13) (102,)

# %% [markdown]
# # now start building neural Network

# %%
model = Sequential()
model.add(Dense(100,input_shape=(13,)))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('linear'))

model.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_6 (Dense)              (None, 100)               1400
# _________________________________________________________________
# activation_3 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_4 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 100)               10100
# _________________________________________________________________
# activation_5 (Activation)    (None, 100)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 101
# ...

# %% [markdown]
# #  Model Compilation

# %%
model.compile(optimizer='adam',
             loss='mean_squared_error',
             metrics=['mse'])

# %%
model.fit(X_train, y_train,
         batch_size=32,
         epochs=50,
         verbose=2,
         validation_data=(X_test, y_test))
# Out:
# Train on 404 samples, validate on 102 samples
# Epoch 1/50
#  - 0s - loss: 69.4440 - mse: 69.4440 - val_loss: 44.1052 - val_mse: 44.1052
# Epoch 2/50
#  - 0s - loss: 32.9583 - mse: 32.9583 - val_loss: 35.6669 - val_mse: 35.6669
# Epoch 3/50
#  - 0s - loss: 28.5112 - mse: 28.5112 - val_loss: 34.6324 - val_mse: 34.6324
# Epoch 4/50
#  - 0s - loss: 32.6634 - mse: 32.6634 - val_loss: 63.6816 - val_mse: 63.6816
# Epoch 5/50
#  - 0s - loss: 52.8201 - mse: 52.8201 - val_loss: 37.0241 - val_mse: 37.0241
# Epoch 6/50
#  - 0s - loss: 36.5910 - mse: 36.5910 - val_loss: 32.3694 - val_mse: 32.3694
# Epoch 7/50
#  - 0s - loss: 27.9546 - mse: 27.9546 - val_loss: 33.4965 - val_mse: 33.4965
# Epoch 8/50
#  - 0s - loss: 27.4669 - mse: 27.4669 - val_loss: 44.3987 - val_mse: 44.3986
# Epoch 9/50
#  - 0s - loss: 32.9352 - mse: 32.9352 - val_loss: 31.1297 - val_mse: 31.1297
# Epoch 10/50
#  - 0s - loss: 26.5567 - mse: 26.5567 - val_loss: 29.8907 - val_mse: 29.8907
# Epoch 11/50
# ...

# %% [markdown]
# # Assignment

# %% [markdown]
# Besides trying different sizes of hidden layers, also try different batch_sizes (1, 2, 4, 8, 16, 32, 64)

# %%
model = Sequential()
model.add(Dense(100,input_shape=(13,)))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
# model.add(Dense(100))
# model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('linear'))
model.summary()


model.compile(optimizer='adam',
             loss='mean_squared_error',
             metrics=['mse'])

model.fit(X_train, y_train,
         batch_size=32,
         epochs=500,
         verbose=1,
         validation_data=(X_test, y_test))
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_26 (Dense)             (None, 100)               1400
# _________________________________________________________________
# activation_23 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_27 (Dense)             (None, 100)               10100
# _________________________________________________________________
# activation_24 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_28 (Dense)             (None, 1)                 101
# _________________________________________________________________
# activation_25 (Activation)   (None, 1)                 0
# ...
# Total params: 11,601
# Trainable params: 11,601
# Non-trainable params: 0
# ...

# %%
model = Sequential()
model.add(Dense(100,input_shape=(13,)))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dense(1))
model.add(Activation('linear'))
model.summary()


model.compile(optimizer='adam',
             loss='mean_squared_error',
             metrics=['mse'])

model.fit(X_train, y_train,
         batch_size=1,
         epochs=50,
         verbose=1,
         validation_data=(X_test, y_test))
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_35 (Dense)             (None, 100)               1400
# _________________________________________________________________
# activation_32 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_36 (Dense)             (None, 100)               10100
# _________________________________________________________________
# activation_33 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_37 (Dense)             (None, 100)               10100
# _________________________________________________________________
# activation_34 (Activation)   (None, 100)               0
# _________________________________________________________________
# dense_38 (Dense)             (None, 100)               10100
# ...
