# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
import pandas as pd

# %%
from sklearn.datasets import load_boston

# %%
dataset = load_boston()

# %%
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'feature_names', 'DESCR', 'filename'])

# %%
dataset['data'].shape,dataset['target'].shape
# Out:
# ((506, 13), (506,))

# %%
i = 0
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# CRIM

# %%
i = 1
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# ZN

# %%
i = 2
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# INDUS

# %%
i = 3
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# CHAS

# %%
i = 4
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# NOX

# %%
i = 5
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# RM

# %%
i = 6
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# AGE

# %%
i = 7
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# DIS

# %%
i = 8
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# RAD

# %%
i = 9
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# TAX

# %%
i = 10
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# PTRATIO

# %%
i = 11
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# B

# %%
i = 12
print(dataset['feature_names'][i])
X = dataset['data'][:,i]
y = dataset['target']
plt.plot(X,y,'.')
plt.show()
# Out:
# LSTAT

# %%
# Features Weight + Normalization 
# BUilding Model 

X = dataset['data']
y = dataset['target']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test , y_train , y_test = train_test_split(X, y, test_size=0.05)

# %%
print(X_train.shape,y_train.shape)
# Out:
# (480, 13) (480,)

# %%
print(X_test.shape,y_test.shape)
# Out:
# (26, 13) (26,)

# %%
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
reg.score(X_test,y_test)
# Out:
# 0.8287000330634398

# %%
print(reg.coef_)
# Out:
# [-1.07991567e-01  4.60804198e-02  2.80105018e-02  2.83039354e+00
#  -1.82735945e+01  3.74828504e+00  1.80880742e-03 -1.49211665e+00
#   3.27941481e-01 -1.35714140e-02 -9.84188831e-01  8.93998599e-03
#  -5.33694107e-01]

# %%
print(reg.intercept_)
# Out:
# 38.145424944495566

# %%
dataset['feature_names'][0]
# Out:
# 'CRIM'
