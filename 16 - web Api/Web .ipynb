# %%
! pip install request

# %%
import requests

# %%
res = requests.get("http://www.google.com")

# %%
res.status_code   #http code-------> 404 not found  200 means success 
#300 redirect response ..response from diffrent response 
# 500 server perblem
# Out:
# 200

# %%
res.headers
# Out:
# {'Date': 'Sat, 14 Mar 2020 07:18:42 GMT', 'Expires': '-1', 'Cache-Control': 'private, max-age=0', 'Content-Type': 'text/html; charset=ISO-8859-1', 'P3P': 'CP="This is not a P3P policy! See g.co/p3phelp for more info."', 'Content-Encoding': 'gzip', 'Server': 'gws', 'Content-Length': '5619', 'X-XSS-Protection': '0', 'X-Frame-Options': 'SAMEORIGIN', 'Set-Cookie': '1P_JAR=2020-03-14-07; expires=Mon, 13-Apr-2020 07:18:42 GMT; path=/; domain=.google.com; Secure, NID=200=LWvEZ-oUKpaZdPWEBh4ucA1HObptRHUhjq4MIdPw4rIKXq1HCAXIQ9NfkJjKitolUpovmQ3VUuJBVSrGLTg0Xa3xTFbfDJo5yVHox4pLvdwMyd_GKK-eZpv4yj-rVySaW_IFfcoKBp4IDQJy3u0D8C1WQmX8a3AGq6bWDmPPLyk; expires=Sun, 13-Sep-2020 07:18:42 GMT; path=/; domain=.google.com; HttpOnly'}

# %%
res.content   #b means binary 0 and 1
# Out:
# b'<!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="en-IN"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="us71cnjw+jw3bam8Twkr0Q==">(function(){window.google={kEI:\'UoVsXqf8LZ_F4-EPu7uYsA4\',kEXPI:\'0,202106,1151641,5662,730,224,3657,1448,206,3204,10,168,121,762,175,364,975,143,317,4,60,742,75,383,140,106,5,624,455,49,226,85,574,154,103,5,116,414553,712176,1197735,289,125,41,329077,1294,12383,4855,32691,15248,861,28690,369,8819,8384,4858,1362,284,4039,4967,3029,3889,850,3108,4892,3033,1808,4020,978,4784,1,3146,5296,2055,920,873,1217,8989,1,415,1141,7512,2653,2883,21,318,689,1292,1191,1348,1395,1379,520,399,2277,10,2794,1593,1279,2212,202,328,149,1103,840,517,1470,4,48,820,3438,312,1132,4,3,2063,606,1839,184,545,1188,43,144,377,1947,747,429,1053,93,328,1284,16,2927,1425,821,474,1339,29,719,327,712,3227,77
# ...

# %%
# jsbin.com cot the code and paste it

# %%
apiKey = "56ab864eed1845da46f6b03b5646a7aa"
city = "Delhi"
baseUrl = "https://api.openweathermap.org/data/2.5/weather"

url = f"{baseUrl}?q={city}&appid={apiKey}"
print(url)
# Out:
# https://api.openweathermap.org/data/2.5/weather?q=Delhi&appid=56ab864eed1845da46f6b03b5646a7aa

# %%
# request sending

# %%
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
res.headers
# Out:
# {'Server': 'openresty', 'Date': 'Sat, 14 Mar 2020 07:40:14 GMT', 'Content-Type': 'application/json; charset=utf-8', 'Content-Length': '455', 'Connection': 'keep-alive', 'X-Cache-Key': '/data/2.5/weather?q=delhi', 'Access-Control-Allow-Origin': '*', 'Access-Control-Allow-Credentials': 'true', 'Access-Control-Allow-Methods': 'GET, POST'}

# %%
res.content
# Out:
# b'{"coord":{"lon":77.22,"lat":28.67},"weather":[{"id":721,"main":"Haze","description":"haze","icon":"50d"}],"base":"stations","main":{"temp":295.15,"feels_like":294.2,"temp_min":295.15,"temp_max":295.15,"pressure":1015,"humidity":68},"visibility":2500,"wind":{"speed":4.1,"deg":100},"clouds":{"all":40},"dt":1584171271,"sys":{"type":1,"id":9165,"country":"IN","sunrise":1584147713,"sunset":1584190729},"timezone":19800,"id":1273294,"name":"Delhi","cod":200}'

# %%
data =res.json()  #noe dictonery is created 
data
# Out:
# {'coord': {'lon': 77.22, 'lat': 28.67},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 295.15,
#   'feels_like': 294.2,
#   'temp_min': 295.15,
#   'temp_max': 295.15,
#   'pressure': 1015,
#   'humidity': 68},
#  'visibility': 2500,
#  'wind': {'speed': 4.1, 'deg': 100},
#  'clouds': {'all': 40},
#  'dt': 1584171271,
#  'sys': {'type': 1,
#   'id': 9165,
#   'country': 'IN',
#   'sunrise': 1584147713,
#   'sunset': 1584190729},
#  'timezone': 19800,
#  'id': 1273294,
#  'name': 'Delhi',
#  'cod': 200}

# %%
data['main']['temp_min'] #its in clvin then convert it into celsisys
# Out:
# 295.15

# %%
data['main']['temp_min']-273.15
# Out:
# 22.0

# %%
data['main']['temp_max']-273.15
# Out:
# 22.0

# %%
data['weather']  #weather is list here
# Out:
# [{'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}]

# %%
data['weather'][0]
# Out:
# {'id': 721, 'main': 'Haze', 'description': 'haze', 'icon': '50d'}

# %%
data['weather'][0]["description"]
# Out:
# 'haze'

# %% [markdown]
# next example respoinse image

# %% [markdown]
# now we use facebook api  --> graph api

# %%
url="http://graph.facebook.com/4/picture?type=large"
res = requests.get(url)
res.status_code
# Out:
# 200

# %%
res.headers  #jpeg  8kb
# Out:
# {'Last-Modified': 'Mon, 16 Dec 2019 00:16:08 GMT', 'Accept-Ranges': 'bytes', 'x-haystack-needlechecksum': '2760348236', 'x-needle-checksum': '568539172', 'Content-Type': 'image/jpeg', 'x-fb-config-version-olb-prod': '760', 'timing-allow-origin': '*', 'Access-Control-Allow-Origin': '*', 'Cache-Control': 'max-age=1209600, no-transform', 'X-FB-TRIP-ID': '2110182175', 'Date': 'Sat, 14 Mar 2020 07:49:16 GMT', 'Alt-Svc': 'h3-27=":443"; ma=3600', 'Access-Control-Expose-Headers': 'X-FB-CEC-Video-Limit', 'Connection': 'keep-alive', 'Content-Length': '8310'}

# %%
res.content  #content of image with b means vianry string
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x02\x00\x00\x01\x00\x01\x00\x00\xff\xed\x00\x9cPhotoshop 3.0\x008BIM\x04\x04\x00\x00\x00\x00\x00\x80\x1c\x02g\x00\x14aV6GhbltkNv5DdCQ8x0G\x1c\x02(\x00bFBMD01000ac0030000c70600005b0b0000320c0000560d0000960f0000d31400008115000095160000d117000076200000\xff\xe2\x02\x1cICC_PROFILE\x00\x01\x01\x00\x00\x02\x0clcms\x02\x10\x00\x00mntrRGB XYZ \x07\xdc\x00\x01\x00\x19\x00\x03\x00)\x009acspAPPL\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-lcms\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ndesc\x00\x00\x00\xfc\x00\x00\x00^cprt\x00\x00\x01\\\x00\x00\x00\x0bwtpt\x00\x00\x01h\x00\x00\x00\x14bkpt\x00\x00\x01|\x00\x00\x00\x14rXYZ\x00\x00\x01\x90\x00\x00\x00\x14gXYZ\x00\x00\x01\xa4\x00\x00\x00\x14bXYZ\x00\x00\x01\xb8\x00\x00\x00\
# ...

# %% [markdown]
# how to work with file

# %%
with open("output/facebook.jpg","wb") as file:
    file.write(res.content)
#file open mode r wb mode me open krnege a 
#b for binary data 

# we are using web block then not need to file_close

# %% [markdown]
# these all are basinc APIS

# %%
! pip install html5lib

# %%
! pip install bs4
# Out:
# ...
#   Created wheel for bs4: filename=bs4-0.0.1-py3-none-any.whl size=1279 sha256=cc802b7a37eeeee885ca2166ebea9fad90ad03ca94b3f1803016ddbba3cd37c4
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\19\f5\6d\a97dd4f22376d4472d5f4c76c7646876052ff3166b3cf71050
# Successfully built bs4
# ...

# %%
from bs4 import BeautifulSoup

# %%
res = requests.get("https://www.flipkart.com")
res
# Out:
# <Response [200]>

# %%
res.headers
# Out:
# {'Server': 'nginx', 'Date': 'Sat, 14 Mar 2020 08:07:01 GMT', 'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Content-Security-Policy': "script-src 'self' 'unsafe-eval' https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://dpm.demdex.net https://sslwidget.criteo.com https://widget.as.criteo.com https://tnc.phonepe.com 'nonce-12090229154239516362'; style-src 'self' 'unsafe-inline' https://*.flixcart.com https://tnc.phonepe.com https://*.flixcart.net; img-src 'self' data: blob: https://*.flixcart.com https://*.flixcart.net https://flipkart.d1.sc.omtrdc.net https://www.facebook.com https://*.fkapi.net https://googleads.g.doubleclick.net https://www.google.com https://www.google.co.in https://www.googleadservices.com https://sp.analytics.yahoo.com https://bat.bing.com https://bat.r.msn.com https://pay.payzippy.com https://1.pay.payzippy.com https://tnc.phonepe.com; font-src 'self' data: https://*.flixcart.com https://tnc.phone
# ...

# %%
res.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<link href="https://rukminim1.flixcart.com" rel="dns-prefetch" />\n\t<link href="https://img1a.flixcart.com" rel="dns-prefetch" />\n\t<link rel="stylesheet" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/css/app.chunk.818233.css" />\n\n\t<link rel="preload" href="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/fk-logo_9fddff.png" as="image">\n\n\t<meta http-equiv="Content-type" content="text/html; charset=utf-8"/>\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge" />\n\t<meta property="fb:page_id" content="102988293558"/>\n\t<meta property="fb:admins" content="658873552,624500995,100000233612389"/>\n\t<meta name="robots" content="noodp" />\n\n\t<link rel=\'shortcut icon\' href="https://img1a.flixcart.com/www/promos/new/20150528-140547-favicon-retina.ico" />\n\n\t<link type="application/opensearchdescription+xml" rel="search" href="/osdd.xml?v=2"/>\n\n\t<meta property="og:type" content="website"/>\n\t<meta name="og_site_name" pr
# ...

# %%
soup = BeautifulSoup(res.content)

# %%
imgList=soup.findAll('img')

# %%
imgList[0]
# Out:
# <img alt="Flipkart" class="_1e_EAo" src="//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png" title="Flipkart" width="75"/>

# %%
imgList[0]['src']
# Out:
# '//img1a.flixcart.com/www/linchpin/fk-cp-zion/img/flipkart-plus_4ee2f9.png'

# %%
use these loop to extract alll src and downlad image s

# %% [markdown]
# # claass name exrraction

# %%
imgList[0]["class"]
# Out:
# ['_1e_EAo']

# %%
# for all image we can use loop or list compirihencion
[img['class'] for img in imgList]  

# key error means .. index out of bond ar key does not exist 
so there si some images where class name are not used so they get error
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-43-bcffa7222998> in <module>
#       1 # for all image we can use loop or list compirihencion
# ----> 2 [img['class'] for img in imgList]
#
# <ipython-input-43-bcffa7222998> in <listcomp>(.0)
#       1 # for all image we can use loop or list compirihencion
# ----> 2 [img['class'] for img in imgList]
#
# c:\users\lenovo\appdata\local\programs\python\python36\lib\site-packages\bs4\element.py in __getitem__(self, key)
#    1319         """tag[key] returns the value of the 'key' attribute for the Tag,
#    1320         and throws an exception if it's not there."""
# -> 1321         return self.attrs[key]
#    1322
#    1323     def __iter__(self):
#
# KeyError: 'class'

# %%
[img.get('class') for img in imgList]   #it si the best way of using
# Out:
# [['_1e_EAo'],
#  None,
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH'],
#  ['_2iEw0G'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1mkrTD'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_1Nyybr'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  ['_232NW7'],
#  ['_2VeolH', '_3I5S6S'],
#  None,
#  None,
#  None,
#  None,
#  None]

# %% [markdown]
# # SEcond Example  by specific class name

# %%
soup.findAll('img', attrs={'class': '_3I5S6S'})
# Out:
# [<img alt="Pigeon" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/62dbf18c602040f1.jpg?q=50"/>,
#  <img alt="Wildcraft" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/80e1c420cb6c15c8.jpg?q=50"/>,
#  <img alt="Cat_Mob_HPW7_IQoo4" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/b2d63ca739f8a75b.jpg?q=50"/>,
#  <img alt="Pigeon" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/62dbf18c602040f1.jpg?q=50"/>,
#  <img alt="dc" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/9581455d64cad13b.jpg?q=50"/>,
#  <img alt="WashAffnity_DTX3_25thJune" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/506475aabd636126.jpg?q=50"/>,
#  <img alt="D" class="_2VeolH _3I5S6S" src="https://rukminim1.flixcart.com/flap/50/50/image/ca450c767c7b095b.jpg?q=50"/>,
# ...

# %%
# length of images

# %%
# for find the prices of images

divList = soup.findAll('div', attrs={'class':"BXlZdc"})
divList
len(divList)
# Out:
# 20

# %%
divList[0].get('class')
# Out:
# ['BXlZdc']

# %%
divList
# Out:
# [<div class="BXlZdc">Extra 10% off</div>,
#  <div class="BXlZdc">From ₹49</div>,
#  <div class="BXlZdc">From ₹319</div>,
#  <div class="BXlZdc">From ₹199+Extra 5%</div>,
#  <div class="BXlZdc">From ₹199</div>,
#  <div class="BXlZdc">Upto 80%+Extra 5% Off</div>,
#  <div class="BXlZdc">From ₹199+Extra 5%Off</div>,
#  <div class="BXlZdc">From ₹99 + 10% Off</div>,
#  <div class="BXlZdc">Extra 5% Off</div>,
#  <div class="BXlZdc">Extra 1 off</div>,
#  <div class="BXlZdc">Extra 5% Off</div>,
#  <div class="BXlZdc">Extra 5% Off</div>,
#  <div class="BXlZdc">Extra 5% off</div>,
#  <div class="BXlZdc">Top Offers</div>,
#  <div class="BXlZdc">Extra 10% Off</div>,
#  <div class="BXlZdc">Extra 30% Off</div>,
#  <div class="BXlZdc">Special Offers</div>,
#  <div class="BXlZdc">Extra 5% Off</div>,
#  <div class="BXlZdc">Extra 10% Off</div>,
#  <div class="BXlZdc">Extra 10% Off</div>]

# %%
divList[0].text
# Out:
# 'Extra 10% off'

# %%
[d.text for d in divList]
# Out:
# ['Extra 10% off',
#  'From ₹49',
#  'From ₹319',
#  'From ₹199+Extra 5%',
#  'From ₹199',
#  'Upto 80%+Extra 5% Off',
#  'From ₹199+Extra 5%Off',
#  'From ₹99 + 10% Off',
#  'Extra 5% Off',
#  'Extra 1 off',
#  'Extra 5% Off',
#  'Extra 5% Off',
#  'Extra 5% off',
#  'Top Offers',
#  'Extra 10% Off',
#  'Extra 30% Off',
#  'Special Offers',
#  'Extra 5% Off',
#  'Extra 10% Off',
#  'Extra 10% Off']

# %% [markdown]
# above is known as web cralling
